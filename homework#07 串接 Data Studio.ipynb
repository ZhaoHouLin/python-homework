# %% [markdown]
# # 作業 #07：串接 Data Studio

# %% [markdown]
# ## 題目描述
# 請在你上傳到「Google Sheet」資料連接到「Google Data Studio」的報表中，嘗試將結果用合理的方式進行呈現。

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://tw.buy.yahoo.com/search/product?p=iPhone-12-128G'
r = requests.get(url)
response = r.text
soup = BeautifulSoup(r.text)

items = soup.find('div', class_='main') \
            .find('ul', class_='gridList') \
            .find_all('li', class_='BaseGridItem__grid___2wuJ7')

links = [ item.find('a')['href'] for item in items ]

products = []

for link in links:
    r = requests.get(link)
    response = r.text
    soup = BeautifulSoup(r.text)

    product = {}
    product['網址'] = link
    product['商品名稱'] = soup.find('h1', class_='HeroInfo__title___57Yfg HeroInfo__textTooLong___BXk8j').text
    product['價錢'] = soup.find('div', class_='HeroInfo__mainPrice___1xP9H').text
    product['價錢'] = product['價錢'][1:].replace(',', '')
    product['優惠'] = soup.find('div', class_='InfoCell__cellContentWrap___2yfZW').text
    products.append(product)
    
products
# Out:
# [{'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-6-1吋智慧型手機-9330891.html',
#   '商品名稱': 'Apple iPhone 12 128G 6.1吋智慧型手機',
#   '價錢': '24500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-6-1吋-128G-5G手機-9216751.html',
#   '商品名稱': 'Apple iPhone 12 6.1吋 128G 5G手機',
#   '價錢': '24500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-6-1吋智慧型手機-9693424.html',
#   '商品名稱': 'Apple iPhone 12 128G 6.1吋智慧型手機',
#   '價錢': '23765',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-6-1吋智慧型手機-9720590.html',
#   '商品名稱': 'Apple iPhone 12 128G 6.1吋智慧型手機',
#   '價錢': '23711',
#   '優惠': '滿額贈滿1件送'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-mini-128G-5-4吋-紫色-智慧型手機-9486263.html',
#   '商品名稱': 'Apple iPhone 12 mini 128G 5.4吋 紫色 智慧型手機',
#   '價錢': '25500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-6-1吋-紫色-智慧型手機-9486259.html',
#   '商品名稱': 'Apple iPhone 12 128G 6.1吋 紫色 智慧型手機',
#   '價錢': '24500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/2020-Apple-iPhone-12-128G-6-1吋智慧型手機-9218365.html',
#   '商品名稱': '2020 Apple iPhone 12 128G 6.1吋智慧型手機',
#   '價錢': '24500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-5G手機-9717373.html',
#   '商品名稱': 'Apple iPhone 12  128G-5G手機',
#   '價錢': '23765',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-mini-128G-5-4吋智慧型手機-紫色-9491743.html',
#   '商品名稱': 'Apple iPhone 12 mini 128G 5.4吋智慧型手機 (紫色)',
#   '價錢': '25500',
#   '優惠': '活動滿999出貨'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/福利品-Apple-iPhone-12-128G-6-1吋手機-電池健康度100-外觀無傷-9264684.html',
#   '商品名稱': '【福利品】Apple  iPhone 12 128G 6.1吋手機 電池健康度100% 外觀無傷',
#   '價錢': '22999',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-mini-128G-5-4吋智慧型手機-紫-9527775.html',
#   '商品名稱': 'Apple iPhone 12 mini 128G 5.4吋智慧型手機-紫',
#   '價錢': '21500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/Apple-iPhone-12-128G-6-1吋智慧型手機-9454343.html',
#   '商品名稱': 'Apple iPhone 12 128G 6.1吋智慧型手機',
#   '價錢': '28500',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/福利品-Apple-iPhone-12-Pro-128G-6-1吋智慧型手機-九成新-9757714.html',
#   '商品名稱': '【福利品】Apple iPhone 12 Pro 128G 6.1吋智慧型手機(九成新)',
#   '價錢': '28090',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/拆封展示機-iPhone-12-128G-6-1吋-白色-MGJC3TA-9690172.html',
#   '商品名稱': '拆封新機 9成9新 iPhone 12 128G 6.1吋 藍色 MGJE3TA/A',
#   '價錢': '22050',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'},
#  {'網址': 'https://tw.buy.yahoo.com/gdsale/展示福利機-Apple-iPhone-12-Pro-Max-128G-銀色-MGD83TA-9755433.html',
#   '商品名稱': '展示福利機 Apple iPhone 12 Pro Max 128G  銀色 MGD83TA',
#   '價錢': '29900',
#   '優惠': '賺翻啦！Yahoo聯名卡返利29%～即辦即用再享現折100'}]

# %%
import requests
from bs4 import BeautifulSoup

headers = {
  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'  
}

url = 'https://m.momoshop.com.tw/search.momo?_advFirst=N&_advCp=N&curPage=1&searchType=&cateLevel=-1&ent=k&searchKeyword=iphone12%20128G&_advThreeHours=N&_isFuzzy=0&_imgSH=fourCardType'
r = requests.get(url, headers=headers)
response = r.text
soup = BeautifulSoup(r.text)

soup.find('h3', class_='prdName')

links = [item.a['href'] for item in soup.find_all('li', class_="goodsItemLi")]

products = []

for link in links:
    
    link = f"https://www.momoshop.com.tw/goods/GoodsDetail.jsp?{link.split('?')[1]}"
    
    r = requests.get(link, headers=headers)
    response = r.text
    soup = BeautifulSoup(r.text)

    product = {}
    product['網址'] = link
    product['商品名稱'] = soup.find('div', class_='prdnoteArea').h3.text
    product['價錢'] = soup.find('ul', class_='prdPrice').find('li', class_='special').span.text
    product['價錢'] = product['價錢'].replace(',', '')
    product['優惠'] = soup.find('li', id='promoThDesc').text.strip().split('\n')[0]
    products.append(product)
    
products
# Out:
# [{'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8286931&mdiv=searchEngine&oid=1_1&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '22990',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9037123&mdiv=searchEngine&oid=1_2&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '19500',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9249481&mdiv=searchEngine&oid=1_3&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '21990',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9456054&mdiv=searchEngine&oid=1_4&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '24799',
#   '優惠': '滿1件折501'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9037125&mdiv=searchEngine&oid=1_5&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '17600',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9037122&mdiv=searchEngine&oid=1_6&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '25555',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9305306&mdiv=searchEngine&oid=1_7&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '21490',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8659089&mdiv=searchEngine&oid=1_8&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '28490',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9015358&mdiv=searchEngine&oid=1_9&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '29355',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9430586&mdiv=searchEngine&oid=1_10&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '23268',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9483019&mdiv=searchEngine&oid=1_11&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '23999',
#   '優惠': '滿1件折501'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9247091&mdiv=searchEngine&oid=1_12&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '21490',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9485746&mdiv=searchEngine&oid=1_13&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '30888',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9434593&mdiv=searchEngine&oid=1_14&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '29992',
#   '優惠': '滿1件享92折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9424929&mdiv=searchEngine&oid=1_15&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '29992',
#   '優惠': '滿1件享92折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9512555&mdiv=searchEngine&oid=1_16&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '26330',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9504780&mdiv=searchEngine&oid=1_17&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '28800',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9512549&mdiv=searchEngine&oid=1_18&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '27280',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=7728139&mdiv=searchEngine&oid=1_19&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '1321',
#   '優惠': '滿1件享95折'},
#  {'網址': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9512548&mdiv=searchEngine&oid=1_20&kw=iphone12 128G',
#   '商品名稱': '\n',
#   '價錢': '26805',
#   '優惠': '滿1件享95折'}]

# %%
import pandas as pd
from datetime import datetime

df1 = pd.DataFrame(products)
df1['來源'] = 'Yahoo'
df1['建立時間'] = datetime.today()

df1

df2 = pd.DataFrame(products)
df2['來源'] = 'Momo'
df2['建立時間'] = datetime.today()

df2
# Out:
#                                                    網址 商品名稱     價錢       優惠  \
# 0   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  22990  滿1件享95折
# 1   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  19500  滿1件享95折
# 2   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  21990  滿1件享95折
# 3   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  24799  滿1件折501
# 4   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  17600  滿1件享95折
# 5   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  25555  滿1件享95折
# 6   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  21490  滿1件享95折
# 7   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  28490  滿1件享95折
# 8   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  29355  滿1件享95折
# 9   https://www.momoshop.com.tw/goods/GoodsDetail....   \n  23268  滿1件享95折
# 10  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  23999  滿1件折501
# 11  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  21490  滿1件享95折
# 12  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  30888  滿1件享95折
# 13  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  29992  滿1件享92折
# 14  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  29992  滿1件享92折
# 15  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  26330  滿1件享95折
# 16  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  28800  滿1件享95折
# 17  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  27280  滿1件享95折
# 18  https://www.momoshop.com.tw/goods/GoodsDetail....   \n   1321  滿1件享95折
# 19  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  26805  滿1件享95折
#
#       來源                       建立時間
# 0   Momo 2021-11-07 10:25:57.270009
# 1   Momo 2021-11-07 10:25:57.270009
# 2   Momo 2021-11-07 10:25:57.270009
# 3   Momo 2021-11-07 10:25:57.270009
# 4   Momo 2021-11-07 10:25:57.270009
# 5   Momo 2021-11-07 10:25:57.270009
# 6   Momo 2021-11-07 10:25:57.270009
# 7   Momo 2021-11-07 10:25:57.270009
# 8   Momo 2021-11-07 10:25:57.270009
# 9   Momo 2021-11-07 10:25:57.270009
# 10  Momo 2021-11-07 10:25:57.270009
# 11  Momo 2021-11-07 10:25:57.270009
# 12  Momo 2021-11-07 10:25:57.270009
# 13  Momo 2021-11-07 10:25:57.270009
# 14  Momo 2021-11-07 10:25:57.270009
# 15  Momo 2021-11-07 10:25:57.270009
# 16  Momo 2021-11-07 10:25:57.270009
# 17  Momo 2021-11-07 10:25:57.270009
# 18  Momo 2021-11-07 10:25:57.270009
# 19  Momo 2021-11-07 10:25:57.270009

# %%
df1.head()
df2.head()
# Out:
#                                                   網址 商品名稱     價錢       優惠  \
# 0  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  22990  滿1件享95折
# 1  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  19500  滿1件享95折
# 2  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  21990  滿1件享95折
# 3  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  24799  滿1件折501
# 4  https://www.momoshop.com.tw/goods/GoodsDetail....   \n  17600  滿1件享95折
#
#      來源                       建立時間
# 0  Momo 2021-11-07 10:25:57.270009
# 1  Momo 2021-11-07 10:25:57.270009
# 2  Momo 2021-11-07 10:25:57.270009
# 3  Momo 2021-11-07 10:25:57.270009
# 4  Momo 2021-11-07 10:25:57.270009

# %%
import pygsheets
KEY_FILE_LOCATION = 'focal-pathway-331301-07f150922c8e.json'
SHEET_ID = '1T7LlfS3MdWtIdQjLVWsVD4HHI5tGbLP-hsFr1aIrAng'
gc = pygsheets.authorize(service_file=KEY_FILE_LOCATION)
sht = gc.open_by_key(SHEET_ID)
wks = sht.worksheet_by_title('sample')

# 將 df1（Yahoo）的結果更新到 Google Sheet
wks.clear()
wks.set_dataframe(df1, 'A1', copy_head=True)

# 將 df2（Momo）的結果更新到 Google Sheet
wks.clear()
wks.set_dataframe(df2, 'A1', copy_head=True)

# 將 df1 + df2 的結果合併後更新到 Google Sheet
wks.clear()
wks.set_dataframe(pd.concat([df1,df2]), 'A1', copy_head=True)

# %% [markdown]
# ## Data Studio

# %% [markdown]
# https://datastudio.google.com/u/0/reporting/77377032-f9be-4092-875f-52834456b7a8/page/BNveC
